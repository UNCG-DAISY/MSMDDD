# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Images/Incident/labels.csv')
data
# Out:
#                     tid  1  2  4
# 0    907998269388836864  0  0  1
# 1    908098386599059457  0  0  1
# 2    907334271777591298  0  0  1
# 3    907051293134422016  1  1  0
# 4    907740144895225856  0  1  0
# 5    907376494514761728  0  1  0
# 6    907686186810044422  0  0  1
# 7    907377318561271810  0  0  1
# 8    907238810769149952  0  1  1
# 9    907715955421323266  0  0  1
# 10   907371656871661568  0  0  1
# 11   907273978930241536  0  0  1
# 12   907992558583910400  0  0  1
# 13   907991768733536256  0  0  1
# 14   907745741057257474  1  1  0
# 15   907164497764384768  0  0  1
# 16   907775787524292609  0  0  1
# 17   907235759798800384  0  1  0
# 18   907996403586289670  0  0  1
# 19   907228783027081219  0  0  1
# 20   907244478691409920  0  1  0
# 21   907578959411511296  0  1  1
# 22   907986284123246593  0  0  1
# 23   907719819226730496  0  0  1
# 24   907638609376923654  0  1  0
# 25   907273685245054976  0  0  1
# 26   907461245904793600  0  1  0
# ...

# %%
for _, row in data.iterrows():
    f = open('InceptionV3/Incident/image_labels_dir/%s.jpg.txt' % row['tid'], 'w')
    if row['1'] == 1:
        f.write('1\n')
    if row['2'] == 1:
        f.write('2\n')
    if row['4'] == 1:
        f.write('4\n')
