# %%
from keras.applications import inception_v3
import keras
import tensorflow as tf
import pandas as pd
import numpy as np
from skimage import io,transform
import os
import sys
model_name = 'InceptionV3_Incident'
# Out:
# Using TensorFlow backend.

# %%
# counter = 0
# folder = '../Images/Incident/'
# data = pd.read_csv(os.path.join(folder, 'labels.csv'))
# imageFiles = os.listdir(folder)
# total = len(imageFiles)
# images = []
# labels = []
# size = 299
# for image_file in imageFiles:
#     if not image_file.endswith('.jpg'):
#         continue
#     img = io.imread(os.path.join(folder,image_file))
#     img = transform.resize(img, (size,size,3))
#     image_file = image_file.split('.')[0]
#     images.append(img)
#     labels.append(data[data.tid == float(image_file)].values[0][1:])
#     counter += 1
#     sys.stdout.write("\rProcessed: {0}/{1}".format(counter, total))
#     sys.stdout.flush()

# x = np.arratfy(images)
# y = np.array(labels)


# np.save('../Images/Incident/incident_x%s.npy' % size, x)
# np.save('../Images/Incident/incident_y%s.npy' % size, y)

# %%
size = 128
x = np.load('../Images/Incident/incident_x%s.npy' % size)
y = np.load('../Images/Incident/incident_y%s.npy' % size)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=7)

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from keras.layers import GlobalAveragePooling2D, Dropout, Dense
from keras.models import Model
base = inception_v3.InceptionV3(include_top=False, weights=None, classes=3, input_shape=(size,size,3), pooling='avg')
temp = base.output
# temp = GlobalAveragePooling2D()(temp)
temp = Dropout(0.5)(temp)
predictions = Dense(3, activation= 'sigmoid')(temp)
model = Model(inputs = base.input, outputs = predictions)

# %%
from keras.callbacks import ModelCheckpoint
# rmsp = rmsprop(lr=0.01, decay=0.9, epsilon=1, clipvalue=2)
model.compile(loss='binary_crossentropy',
              optimizer='sgd',
              metrics=['acc'])

filepath="%s.best.hdf5" % model_name
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

hist = model.fit([x_train], y_train, batch_size=32, epochs=100, validation_data=([x_test], y_test), verbose=1, callbacks=callbacks_list)
# Out:
# Train on 630 samples, validate on 158 samples
# Epoch 1/100
# 630/630 [==============================] - 7s 11ms/step - loss: 0.6327 - acc: 0.6799 - val_loss: 2.2229 - val_acc: 0.7447
#
# Epoch 00001: val_loss improved from inf to 2.22292, saving model to InceptionV3_Incident.best.hdf5
# Epoch 2/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5980 - acc: 0.7106 - val_loss: 1.5113 - val_acc: 0.6308
#
# Epoch 00002: val_loss improved from 2.22292 to 1.51129, saving model to InceptionV3_Incident.best.hdf5
# Epoch 3/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5848 - acc: 0.7238 - val_loss: 0.7612 - val_acc: 0.7384
#
# Epoch 00003: val_loss improved from 1.51129 to 0.76122, saving model to InceptionV3_Incident.best.hdf5
# Epoch 4/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5756 - acc: 0.7233 - val_loss: 1.2817 - val_acc: 0.7384
#
# Epoch 00004: val_loss did not improve from 0.76122
# Epoch 5/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5671 - acc: 0.7365 - val_loss: 2.0107 - val_acc: 0.7532
#
# Epoch 00005: val_loss did not improve from 0.76122
# Epoch 6/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5521 - acc: 0.7460 - val_loss: 2.3967 - val_acc: 0.7468
#
# Epoch 00006: val_loss did not improve from 0.76122
# Epoch 7/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5308 - acc: 0.7619 - val_loss: 1.8460 - val_acc: 0.7278
#
# Epoch 00007: val_loss did not improve from 0.76122
# Epoch 8/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5321 - acc: 0.7524 - val_loss: 2.8409 - val_acc: 0.7384
#
# Epoch 00008: val_loss did not improve from 0.76122
# Epoch 9/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5330 - acc: 0.7513 - val_loss: 1.4018 - val_acc: 0.7426
#
# Epoch 00009: val_loss did not improve from 0.76122
# Epoch 10/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5259 - acc: 0.7619 - val_loss: 1.4626 - val_acc: 0.6814
#
# Epoch 00010: val_loss did not improve from 0.76122
# Epoch 11/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5094 - acc: 0.7646 - val_loss: 0.9995 - val_acc: 0.7257
#
# Epoch 00011: val_loss did not improve from 0.76122
# Epoch 12/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.5013 - acc: 0.7646 - val_loss: 0.7122 - val_acc: 0.6857
#
# Epoch 00012: val_loss improved from 0.76122 to 0.71219, saving model to InceptionV3_Incident.best.hdf5
# Epoch 13/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4812 - acc: 0.7831 - val_loss: 0.5659 - val_acc: 0.7447
#
# Epoch 00013: val_loss improved from 0.71219 to 0.56591, saving model to InceptionV3_Incident.best.hdf5
# Epoch 14/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4852 - acc: 0.7788 - val_loss: 0.5541 - val_acc: 0.7553
#
# Epoch 00014: val_loss improved from 0.56591 to 0.55415, saving model to InceptionV3_Incident.best.hdf5
# Epoch 15/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4640 - acc: 0.7878 - val_loss: 0.6018 - val_acc: 0.7532
#
# Epoch 00015: val_loss did not improve from 0.55415
# Epoch 16/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4628 - acc: 0.7788 - val_loss: 0.6948 - val_acc: 0.7131
#
# Epoch 00016: val_loss did not improve from 0.55415
# Epoch 17/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4601 - acc: 0.7899 - val_loss: 0.7401 - val_acc: 0.6793
#
# Epoch 00017: val_loss did not improve from 0.55415
# Epoch 18/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4375 - acc: 0.8063 - val_loss: 0.5189 - val_acc: 0.7848
#
# Epoch 00018: val_loss improved from 0.55415 to 0.51894, saving model to InceptionV3_Incident.best.hdf5
# Epoch 19/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4267 - acc: 0.8212 - val_loss: 0.5113 - val_acc: 0.7785
#
# Epoch 00019: val_loss improved from 0.51894 to 0.51125, saving model to InceptionV3_Incident.best.hdf5
# Epoch 20/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4126 - acc: 0.8201 - val_loss: 0.5817 - val_acc: 0.7257
#
# Epoch 00020: val_loss did not improve from 0.51125
# Epoch 21/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4143 - acc: 0.8122 - val_loss: 0.4969 - val_acc: 0.7511
#
# Epoch 00021: val_loss improved from 0.51125 to 0.49691, saving model to InceptionV3_Incident.best.hdf5
# Epoch 22/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.3993 - acc: 0.8143 - val_loss: 0.6405 - val_acc: 0.6983
#
# Epoch 00022: val_loss did not improve from 0.49691
# Epoch 23/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.4003 - acc: 0.8249 - val_loss: 0.5091 - val_acc: 0.7342
#
# Epoch 00023: val_loss did not improve from 0.49691
# Epoch 24/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.3586 - acc: 0.8497 - val_loss: 0.5146 - val_acc: 0.7722
#
# Epoch 00024: val_loss did not improve from 0.49691
# Epoch 25/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.3515 - acc: 0.8487 - val_loss: 0.4830 - val_acc: 0.8017
#
# Epoch 00025: val_loss improved from 0.49691 to 0.48305, saving model to InceptionV3_Incident.best.hdf5
# Epoch 26/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.3334 - acc: 0.8503 - val_loss: 0.5007 - val_acc: 0.7637
#
# Epoch 00026: val_loss did not improve from 0.48305
# Epoch 27/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.3219 - acc: 0.8608 - val_loss: 0.5026 - val_acc: 0.7722
#
# Epoch 00027: val_loss did not improve from 0.48305
# Epoch 28/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.3126 - acc: 0.8672 - val_loss: 0.5216 - val_acc: 0.7468
#
# Epoch 00028: val_loss did not improve from 0.48305
# Epoch 29/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.3019 - acc: 0.8847 - val_loss: 0.5370 - val_acc: 0.7447
#
# Epoch 00029: val_loss did not improve from 0.48305
# Epoch 30/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.2731 - acc: 0.8794 - val_loss: 0.5185 - val_acc: 0.7595
#
# Epoch 00030: val_loss did not improve from 0.48305
# Epoch 31/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.2608 - acc: 0.8889 - val_loss: 0.6599 - val_acc: 0.6941
#
# Epoch 00031: val_loss did not improve from 0.48305
# Epoch 32/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.2417 - acc: 0.8974 - val_loss: 0.5721 - val_acc: 0.7426
#
# Epoch 00032: val_loss did not improve from 0.48305
# Epoch 33/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.2593 - acc: 0.8968 - val_loss: 0.5083 - val_acc: 0.7616
#
# Epoch 00033: val_loss did not improve from 0.48305
# Epoch 34/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.2340 - acc: 0.8979 - val_loss: 0.6245 - val_acc: 0.7110
#
# Epoch 00034: val_loss did not improve from 0.48305
# Epoch 35/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.2187 - acc: 0.9222 - val_loss: 0.6871 - val_acc: 0.7110
#
# Epoch 00035: val_loss did not improve from 0.48305
# Epoch 36/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.2042 - acc: 0.9249 - val_loss: 0.7016 - val_acc: 0.7384
#
# Epoch 00036: val_loss did not improve from 0.48305
# Epoch 37/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1887 - acc: 0.9254 - val_loss: 0.5933 - val_acc: 0.7764
#
# Epoch 00037: val_loss did not improve from 0.48305
# Epoch 38/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1643 - acc: 0.9392 - val_loss: 0.7115 - val_acc: 0.6878
#
# Epoch 00038: val_loss did not improve from 0.48305
# Epoch 39/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1697 - acc: 0.9339 - val_loss: 0.6361 - val_acc: 0.7236
#
# Epoch 00039: val_loss did not improve from 0.48305
# Epoch 40/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1523 - acc: 0.9386 - val_loss: 0.6342 - val_acc: 0.7257
#
# Epoch 00040: val_loss did not improve from 0.48305
# Epoch 41/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1737 - acc: 0.9333 - val_loss: 0.7169 - val_acc: 0.7131
#
# Epoch 00041: val_loss did not improve from 0.48305
# Epoch 42/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1364 - acc: 0.9534 - val_loss: 0.5620 - val_acc: 0.7574
#
# Epoch 00042: val_loss did not improve from 0.48305
# Epoch 43/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1375 - acc: 0.9497 - val_loss: 0.6182 - val_acc: 0.7637
#
# Epoch 00043: val_loss did not improve from 0.48305
# Epoch 44/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1390 - acc: 0.9503 - val_loss: 0.6014 - val_acc: 0.7658
#
# Epoch 00044: val_loss did not improve from 0.48305
# Epoch 45/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1283 - acc: 0.9540 - val_loss: 0.5971 - val_acc: 0.7743
#
# Epoch 00045: val_loss did not improve from 0.48305
# Epoch 46/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1078 - acc: 0.9667 - val_loss: 0.6123 - val_acc: 0.7679
#
# Epoch 00046: val_loss did not improve from 0.48305
# Epoch 47/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1007 - acc: 0.9677 - val_loss: 0.6406 - val_acc: 0.7827
#
# Epoch 00047: val_loss did not improve from 0.48305
# Epoch 48/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1065 - acc: 0.9656 - val_loss: 0.5507 - val_acc: 0.7806
#
# Epoch 00048: val_loss did not improve from 0.48305
# Epoch 49/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0944 - acc: 0.9698 - val_loss: 0.6303 - val_acc: 0.7637
#
# Epoch 00049: val_loss did not improve from 0.48305
# Epoch 50/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0973 - acc: 0.9698 - val_loss: 0.6429 - val_acc: 0.7806
#
# Epoch 00050: val_loss did not improve from 0.48305
# Epoch 51/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.1002 - acc: 0.9646 - val_loss: 0.7727 - val_acc: 0.6920
#
# Epoch 00051: val_loss did not improve from 0.48305
# Epoch 52/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0935 - acc: 0.9688 - val_loss: 0.6719 - val_acc: 0.7405
#
# Epoch 00052: val_loss did not improve from 0.48305
# Epoch 53/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0749 - acc: 0.9815 - val_loss: 0.6714 - val_acc: 0.7468
#
# Epoch 00053: val_loss did not improve from 0.48305
# Epoch 54/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0646 - acc: 0.9847 - val_loss: 0.6264 - val_acc: 0.7616
#
# Epoch 00054: val_loss did not improve from 0.48305
# Epoch 55/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0566 - acc: 0.9884 - val_loss: 0.6476 - val_acc: 0.7616
#
# Epoch 00055: val_loss did not improve from 0.48305
# Epoch 56/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0696 - acc: 0.9794 - val_loss: 0.6982 - val_acc: 0.7722
#
# Epoch 00056: val_loss did not improve from 0.48305
# Epoch 57/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0857 - acc: 0.9688 - val_loss: 0.6692 - val_acc: 0.7658
#
# Epoch 00057: val_loss did not improve from 0.48305
# Epoch 58/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0699 - acc: 0.9778 - val_loss: 0.6811 - val_acc: 0.7722
#
# Epoch 00058: val_loss did not improve from 0.48305
# Epoch 59/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0616 - acc: 0.9804 - val_loss: 0.6884 - val_acc: 0.7911
#
# Epoch 00059: val_loss did not improve from 0.48305
# Epoch 60/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0840 - acc: 0.9693 - val_loss: 0.7402 - val_acc: 0.7616
#
# Epoch 00060: val_loss did not improve from 0.48305
# Epoch 61/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0725 - acc: 0.9778 - val_loss: 0.6569 - val_acc: 0.7996
#
# Epoch 00061: val_loss did not improve from 0.48305
# Epoch 62/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0509 - acc: 0.9852 - val_loss: 0.6708 - val_acc: 0.7869
#
# Epoch 00062: val_loss did not improve from 0.48305
# Epoch 63/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0458 - acc: 0.9884 - val_loss: 0.6548 - val_acc: 0.7574
#
# Epoch 00063: val_loss did not improve from 0.48305
# Epoch 64/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0421 - acc: 0.9884 - val_loss: 0.7145 - val_acc: 0.7785
#
# Epoch 00064: val_loss did not improve from 0.48305
# Epoch 65/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0403 - acc: 0.9915 - val_loss: 1.0463 - val_acc: 0.6920
#
# Epoch 00065: val_loss did not improve from 0.48305
# Epoch 66/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0492 - acc: 0.9847 - val_loss: 0.7477 - val_acc: 0.7679
#
# Epoch 00066: val_loss did not improve from 0.48305
# Epoch 67/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0419 - acc: 0.9894 - val_loss: 0.7395 - val_acc: 0.7616
#
# Epoch 00067: val_loss did not improve from 0.48305
# Epoch 68/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0550 - acc: 0.9820 - val_loss: 0.7911 - val_acc: 0.7679
#
# Epoch 00068: val_loss did not improve from 0.48305
# Epoch 69/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0367 - acc: 0.9915 - val_loss: 0.6971 - val_acc: 0.7848
#
# Epoch 00069: val_loss did not improve from 0.48305
# Epoch 70/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0468 - acc: 0.9868 - val_loss: 1.0353 - val_acc: 0.7679
#
# Epoch 00070: val_loss did not improve from 0.48305
# Epoch 71/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0501 - acc: 0.9878 - val_loss: 0.7517 - val_acc: 0.7764
#
# Epoch 00071: val_loss did not improve from 0.48305
# Epoch 72/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0466 - acc: 0.9857 - val_loss: 0.7544 - val_acc: 0.7806
#
# Epoch 00072: val_loss did not improve from 0.48305
# Epoch 73/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0494 - acc: 0.9868 - val_loss: 0.7387 - val_acc: 0.7954
#
# Epoch 00073: val_loss did not improve from 0.48305
# Epoch 74/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0499 - acc: 0.9841 - val_loss: 0.7869 - val_acc: 0.7447
#
# Epoch 00074: val_loss did not improve from 0.48305
# Epoch 75/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0604 - acc: 0.9799 - val_loss: 0.8258 - val_acc: 0.7700
#
# Epoch 00075: val_loss did not improve from 0.48305
# Epoch 76/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0363 - acc: 0.9921 - val_loss: 0.7642 - val_acc: 0.7764
#
# Epoch 00076: val_loss did not improve from 0.48305
# Epoch 77/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0285 - acc: 0.9921 - val_loss: 0.7321 - val_acc: 0.7553
#
# Epoch 00077: val_loss did not improve from 0.48305
# Epoch 78/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0298 - acc: 0.9926 - val_loss: 0.7906 - val_acc: 0.7489
#
# Epoch 00078: val_loss did not improve from 0.48305
# Epoch 79/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0384 - acc: 0.9889 - val_loss: 0.9238 - val_acc: 0.7194
#
# Epoch 00079: val_loss did not improve from 0.48305
# Epoch 80/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0413 - acc: 0.9905 - val_loss: 0.8011 - val_acc: 0.7658
#
# Epoch 00080: val_loss did not improve from 0.48305
# Epoch 81/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0353 - acc: 0.9905 - val_loss: 0.7871 - val_acc: 0.7595
#
# Epoch 00081: val_loss did not improve from 0.48305
# Epoch 82/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0256 - acc: 0.9937 - val_loss: 0.8484 - val_acc: 0.7447
#
# Epoch 00082: val_loss did not improve from 0.48305
# Epoch 83/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0232 - acc: 0.9952 - val_loss: 0.7524 - val_acc: 0.7806
#
# Epoch 00083: val_loss did not improve from 0.48305
# Epoch 84/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0273 - acc: 0.9915 - val_loss: 0.7801 - val_acc: 0.7574
#
# Epoch 00084: val_loss did not improve from 0.48305
# Epoch 85/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0327 - acc: 0.9910 - val_loss: 0.8167 - val_acc: 0.7595
#
# Epoch 00085: val_loss did not improve from 0.48305
# Epoch 86/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0227 - acc: 0.9942 - val_loss: 0.7735 - val_acc: 0.7743
#
# Epoch 00086: val_loss did not improve from 0.48305
# Epoch 87/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0177 - acc: 0.9963 - val_loss: 0.7698 - val_acc: 0.7722
#
# Epoch 00087: val_loss did not improve from 0.48305
# Epoch 88/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0173 - acc: 0.9974 - val_loss: 0.7808 - val_acc: 0.7637
#
# Epoch 00088: val_loss did not improve from 0.48305
# Epoch 89/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0193 - acc: 0.9958 - val_loss: 0.7533 - val_acc: 0.7679
#
# Epoch 00089: val_loss did not improve from 0.48305
# Epoch 90/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0243 - acc: 0.9947 - val_loss: 0.7874 - val_acc: 0.7426
#
# Epoch 00090: val_loss did not improve from 0.48305
# Epoch 91/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0213 - acc: 0.9942 - val_loss: 0.7775 - val_acc: 0.7679
#
# Epoch 00091: val_loss did not improve from 0.48305
# Epoch 92/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0240 - acc: 0.9937 - val_loss: 0.7510 - val_acc: 0.7911
#
# Epoch 00092: val_loss did not improve from 0.48305
# Epoch 93/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0194 - acc: 0.9952 - val_loss: 0.7887 - val_acc: 0.7700
#
# Epoch 00093: val_loss did not improve from 0.48305
# Epoch 94/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0224 - acc: 0.9968 - val_loss: 0.7283 - val_acc: 0.7869
#
# Epoch 00094: val_loss did not improve from 0.48305
# Epoch 95/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0148 - acc: 0.9968 - val_loss: 0.7798 - val_acc: 0.7658
#
# Epoch 00095: val_loss did not improve from 0.48305
# Epoch 96/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0132 - acc: 0.9963 - val_loss: 0.8374 - val_acc: 0.7806
#
# Epoch 00096: val_loss did not improve from 0.48305
# Epoch 97/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0139 - acc: 0.9984 - val_loss: 0.8222 - val_acc: 0.7679
#
# Epoch 00097: val_loss did not improve from 0.48305
# Epoch 98/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0169 - acc: 0.9963 - val_loss: 0.9007 - val_acc: 0.7511
#
# Epoch 00098: val_loss did not improve from 0.48305
# Epoch 99/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0286 - acc: 0.9894 - val_loss: 0.7612 - val_acc: 0.7743
#
# Epoch 00099: val_loss did not improve from 0.48305
# Epoch 100/100
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0243 - acc: 0.9942 - val_loss: 0.8750 - val_acc: 0.7616
#
# Epoch 00100: val_loss did not improve from 0.48305

# %%
# serialize model to JSON
model_json = model.to_json()
with open("%s.json" % model_name, "w") as json_file:
    json_file.write(model_json)
    
# # serialize weights to HDF5
model.save_weights("%s.h5" % model_name)
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json
# load json and create model
json_file = open('%s.json' % model_name, 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("%s.h5" % model_name)
print("Loaded model from disk")

model.compile(loss='binary_crossentropy',
              optimizer='sgd',
              metrics=['acc'])
# Out:
# Loaded model from disk

# %%
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score, roc_auc_score
predicted = model.predict([x_test])
print(classification_report(y_test, predicted > 0.5))
print(precision_score(y_test, predicted > 0.5, average='micro'))
print(recall_score(y_test, predicted > 0.5, average='micro'))
print(roc_auc_score(y_test, predicted > 0.5, average='micro'))
print(f1_score(y_test, predicted > 0.5, average='micro'))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.40      0.18      0.25        22
#           1       0.51      0.49      0.50        51
#           2       0.79      0.89      0.84       111
#
# avg / total       0.66      0.70      0.67       184
#
# 0.6918918918918919
# 0.6956521739130435
# 0.7495502248875562
# 0.6937669376693767

# %%
from keras.models import model_from_json
# load json and create model
json_file = open('%s.json' % model_name, 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("%s.best.hdf5" % model_name)
print("Loaded model from disk")

model.compile(loss='binary_crossentropy',
              optimizer='sgd',
              metrics=['acc'])
# Out:
# Loaded model from disk

# %%
predicted = model.predict([x_test])
print(classification_report(y_test, predicted > 0.5))
print(precision_score(y_test, predicted > 0.5, average='micro'))
print(recall_score(y_test, predicted > 0.5, average='micro'))
print(roc_auc_score(y_test, predicted > 0.5, average='micro'))
print(f1_score(y_test, predicted > 0.5, average='micro'))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.36      0.18      0.24        22
#           1       0.68      0.49      0.57        51
#           2       0.81      0.94      0.87       111
#
# avg / total       0.72      0.72      0.71       184
#
# 0.7556818181818182
# 0.7228260869565217
# 0.7872751124437781
# 0.7388888888888889
